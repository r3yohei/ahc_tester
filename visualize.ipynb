# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
"""
	case	score	K	M	N
count	1000.000000	1000.000000	1000.000000	1000.000000	1000.000000
mean	499.500000	5690.643000	3.492000	4.989000	4.417000
std	288.819436	4661.753424	1.114979	2.002221	1.730348
min	0.000000	713.000000	2.000000	2.000000	2.000000
25%	249.750000	2840.500000	2.000000	3.000000	3.000000
50%	499.500000	4433.500000	3.500000	5.000000	4.000000
75%	749.250000	6968.250000	4.000000	7.000000	6.000000
max	999.000000	48305.000000	5.000000	8.000000	7.000000
"""
# Out:
# '\n\tcase\tscore\tN\ncount\t1000.000000\t1.000000e+03\t1000.000000\nmean\t499.500000\t1.585706e+07\t30.083000\nstd\t288.819436\t1.578032e+07\t6.079397\nmin\t0.000000\t4.391890e+05\t20.000000\n25%\t249.750000\t5.176485e+06\t25.000000\n50%\t499.500000\t1.067096e+07\t30.000000\n75%\t749.250000\t2.162395e+07\t35.000000\nmax\t999.000000\t1.549179e+08\t40.000000\n'

# %%
result = pd.read_csv("./result.csv")
display(result.head())
display(result.describe())
# Out:
#    case  score  K  M  N
# 0     0   2685  3  2  2
# 1     1   2663  2  8  7
# 2     2   9722  5  6  7
# 3     3   7634  4  3  6
# 4     4   4526  3  2  3
#               case         score            K            M            N
# count  1000.000000   1000.000000  1000.000000  1000.000000  1000.000000
# mean    499.500000   5663.646000     3.492000     4.989000     4.417000
# std     288.819436   4734.423864     1.114979     2.002221     1.730348
# min       0.000000    496.000000     2.000000     2.000000     2.000000
# 25%     249.750000   2762.750000     2.000000     3.000000     3.000000
# 50%     499.500000   4380.500000     3.500000     5.000000     4.000000
# 75%     749.250000   6985.000000     4.000000     7.000000     6.000000
# max     999.000000  47505.000000     5.000000     8.000000     7.000000

# %%
rank = 15
print(f"best {rank}")
display(result.sort_values("score", ascending=False).head(rank))
print(f"worst {rank}")
display(result.sort_values("score", ascending=True).head(rank))
# Out:
# best 15
#      case  score  K  M  N
# 255   255  44398  2  4  6
# 200   200  37420  5  7  7
# 45     45  36202  5  4  6
# 736   736  27625  5  4  7
# 328   328  23487  5  7  7
# 473   473  23049  5  3  7
# 218   218  22517  4  5  7
# 442   442  22212  5  5  7
# 41     41  22055  3  4  2
# 486   486  21890  4  8  6
# 25     25  20206  5  6  7
# 648   648  19510  4  5  6
# 424   424  19223  5  8  4
# 314   314  18850  5  7  7
# 762   762  18831  5  7  6
# worst 15
#      case  score  K  M  N
# 453   453    348  2  2  2
# 361   361    464  3  3  3
# 577   577    498  5  6  4
# 763   763    523  3  2  6
# 448   448    592  2  4  2
# 845   845    611  2  3  2
# 796   796    660  3  5  2
# 444   444    687  2  6  6
# 670   670    785  2  2  3
# 829   829    787  2  4  7
# 709   709    825  2  3  7
# 582   582    883  4  2  2
# 57     57    928  2  2  4
# 744   744    957  2  3  5
# 559   559    969  3  4  6

# %%
fig, axes = plt.subplots(2, 2, figsize=(20, 18))
axes = axes.ravel()

for x, ax in zip(["N", "M", "K"], axes):
    sns.barplot(x=x, y="score", data=result, ax=ax)
